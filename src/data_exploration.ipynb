# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
datasets_path = "/home/artorius/Code/ESGI/BI/BI_couscous/datasets/"

# %% [markdown]
# ## Categories

# %%
df_categories = pd.read_csv(f"{datasets_path}categories.csv")
df_categories
# Out:
#     CategoryID CategoryName
# 0            1  Confections
# 1            2   Shell fish
# 2            3      Cereals
# 3            4        Dairy
# 4            5    Beverages
# 5            6      Seafood
# 6            7         Meat
# 7            8        Grain
# 8            9      Poultry
# 9           10       Snails
# 10          11      Produce

# %%
df_categories.describe()
# Out:
#        CategoryID
# count   11.000000
# mean     6.000000
# std      3.316625
# min      1.000000
# 25%      3.500000
# 50%      6.000000
# 75%      8.500000
# max     11.000000

# %% [markdown]
# ## Cities

# %%
df_cities = pd.read_csv(f"{datasets_path}cities.csv")
df_cities
# Out:
#     CityID        CityName  Zipcode  CountryID
# 0        1          Dayton    80563         32
# 1        2         Buffalo    17420         32
# 2        3         Chicago    44751         32
# 3        4         Fremont    20641         32
# 4        5  Virginia Beach    62389         32
# ..     ...             ...      ...        ...
# 91      92         Hialeah    34375         32
# 92      93          Jersey    55355         32
# 93      94         Yonkers     7430         32
# 94      95         Garland    73265         32
# 95      96      Pittsburgh    14257         32
#
# [96 rows x 4 columns]

# %%
df_cities.describe()
# Out:
#           CityID       Zipcode  CountryID
# count  96.000000     96.000000       96.0
# mean   48.500000  51245.302083       32.0
# std    27.856777  29883.397049        0.0
# min     1.000000    157.000000       32.0
# 25%    24.750000  21780.500000       32.0
# 50%    48.500000  51700.000000       32.0
# 75%    72.250000  79867.750000       32.0
# max    96.000000  97859.000000       32.0

# %% [markdown]
# ## Countries

# %%
df_countries = pd.read_csv(f"{datasets_path}countries.csv")
df_countries
# Out:
#      CountryID CountryName CountryCode
# 0            1     Armenia          AN
# 1            2      Canada          FO
# 2            3      Belize          MK
# 3            4      Uganda          LV
# 4            5    Thailand          VI
# ..         ...         ...         ...
# 201        202   Greenland          MW
# 202        203       Niger          SH
# 203        204    Malvinas          GE
# 204        205     Mayotte          PG
# 205        206    Mongolia          MZ
#
# [206 rows x 3 columns]

# %%
df_countries.describe()
# Out:
#         CountryID
# count  206.000000
# mean   103.500000
# std     59.611241
# min      1.000000
# 25%     52.250000
# 50%    103.500000
# 75%    154.750000
# max    206.000000

# %% [markdown]
# ## Customers

# %%
df_customers = pd.read_csv(f"{datasets_path}customers.csv")
df_customers
# Out:
#        CustomerID FirstName MiddleInitial   LastName  CityID  \
# 0               1  Stefanie             Y       Frye      79
# 1               2     Sandy             T      Kirby      96
# 2               3       Lee             T      Zhang      55
# 3               4    Regina             S      Avery      40
# 4               5    Daniel             S     Mccann       2
# ...           ...       ...           ...        ...     ...
# 98754       98755    Yvette             C     Campos      27
# 98755       98756    Angelo             X  Mc Millan      82
# 98756       98757     Shari             J     Prince      81
# 98757       98758    Stuart             K    Cameron      57
# 98758       98759    Willie             E     Lawson      94
#
#                             Address
# 0                     97 Oak Avenue
# 1            52 White First Freeway
# 2           921 White Fabien Avenue
# 3                     75 Old Avenue
# 4      283 South Green Hague Avenue
# ...

# %%
df_customers.describe()
# Out:
#          CustomerID        CityID
# count  98759.000000  98759.000000
# mean   49380.000000     48.557661
# std    28509.411955     27.660082
# min        1.000000      1.000000
# 25%    24690.500000     25.000000
# 50%    49380.000000     49.000000
# 75%    74069.500000     72.000000
# max    98759.000000     96.000000

# %% [markdown]
# ## Employees

# %%
df_employees = pd.read_csv(f"{datasets_path}employees.csv")
df_employees
# Out:
#     EmployeeID  FirstName MiddleInitial   LastName                BirthDate  \
# 0            1     Nicole             T     Fuller  1981-03-07 00:00:00.000
# 1            2  Christine             W     Palmer  1968-01-25 00:00:00.000
# 2            3      Pablo             Y      Cline  1963-02-09 00:00:00.000
# 3            4    Darnell             O    Nielsen  1989-02-06 00:00:00.000
# 4            5    Desiree             L     Stuart  1963-05-03 00:00:00.000
# 5            6      Holly             E    Collins  1987-01-13 00:00:00.000
# 6            7   Chadwick             P       Cook  1970-05-02 00:00:00.000
# 7            8      Julie             E       Dyer  1956-12-13 00:00:00.000
# 8            9     Daphne             X       King  1956-05-02 00:00:00.000
# 9           10       Jean             P       Vang  1963-12-30 00:00:00.000
# 10          11      Sonya             E    Dickson  1976-01-14 00:00:00.000
# ...

# %%
df_employees.describe()
# Out:
#        EmployeeID     CityID
# count    23.00000  23.000000
# mean     12.00000  43.782609
# std       6.78233  26.381737
# min       1.00000   4.000000
# 25%       6.50000  20.500000
# 50%      12.00000  39.000000
# 75%      17.50000  65.000000
# max      23.00000  92.000000

# %% [markdown]
# ## Products

# %%
df_products = pd.read_csv(f"{datasets_path}products.csv")
df_products
# Out:
#      ProductID                      ProductName    Price  CategoryID   Class  \
# 0            1              Flour - Whole Wheat  74.2988           3  Medium
# 1            2       Cookie Chocolate Chip With  91.2329           3  Medium
# 2            3               Onions - Cippolini   9.1379           9  Medium
# 3            4       Sauce - Gravy, Au Jus, Mix  54.3055           9  Medium
# 4            5           Artichokes - Jerusalem  65.4771           2     Low
# ..         ...                              ...      ...         ...     ...
# 447        448         Gatorade - Xfactor Berry  76.8988           5     Low
# 448        449            Nantuket Peach Orange  42.1414           4     Low
# 449        450    Wine - Vidal Icewine Magnotta   7.1070           3     Low
# 450        451  Soup - Campbells Tomato Ravioli  93.5384           1     Low
# 451        452          Napkin White - Starched  28.5653          11     Low
#
# ...

# %%
df_products.describe()
# Out:
#         ProductID       Price  CategoryID  VitalityDays
# count  452.000000  452.000000  452.000000    452.000000
# mean   226.500000   50.801471    5.862832     26.030973
# std    130.625419   28.616724    3.271694     39.061200
# min      1.000000    0.044900    1.000000      0.000000
# 25%    113.750000   26.504350    3.000000      0.000000
# 50%    226.500000   52.499500    6.000000      0.000000
# 75%    339.250000   75.496450    9.000000     52.500000
# max    452.000000   99.875500   11.000000    120.000000

# %% [markdown]
# ## Sales

# %%
df_sales = pd.read_csv(f"{datasets_path}sales.csv")
df_sales
# Out:
#          SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0              1              6       27039        381         7       0.0
# 1              2             16       25011         61         7       0.0
# 2              3             13       94024         23        24       0.0
# 3              4              8       73966        176        19       0.2
# 4              5             10       32653        310         9       0.0
# ...          ...            ...         ...        ...       ...       ...
# 6758120  6758121             10       50938        300        13       0.0
# 6758121  6758122             18       85668        452        22       0.1
# 6758122  6758123             21       68409        405        18       0.0
# 6758123  6758124             17       90315        104        23       0.0
# 6758124  6758125             16       45667        305        12       0.0
#
#          TotalPrice                SalesDate     TransactionNumber
# ...

# %%
df_sales.describe()
# Out:
#             SalesID  SalesPersonID    CustomerID     ProductID      Quantity  \
# count  6.758125e+06   6.758125e+06  6.758125e+06  6.758125e+06  6.758125e+06
# mean   3.379063e+06   1.199972e+01  4.939567e+04  2.265474e+02  1.300401e+01
# std    1.950903e+06   6.632689e+00  2.850504e+04  1.304744e+02  7.209701e+00
# min    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.689532e+06   6.000000e+00  2.470700e+04  1.140000e+02  7.000000e+00
# 50%    3.379063e+06   1.200000e+01  4.941400e+04  2.270000e+02  1.300000e+01
# 75%    5.068594e+06   1.800000e+01  7.407500e+04  3.400000e+02  1.900000e+01
# max    6.758125e+06   2.300000e+01  9.875900e+04  4.520000e+02  2.500000e+01
#
#            Discount  TotalPrice
# count  6.758125e+06   6758125.0
# mean   2.996787e-02         0.0
# std    6.398096e-02         0.0
# min    0.000000e+00         0.0
# 25%    0.000000e+00         0.0
# 50%    0.000000e+00         0.0
# 75%    0.000000e+00         0.0
# ...
